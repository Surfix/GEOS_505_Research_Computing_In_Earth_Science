# %%
# Need to install bmi_nwis if it doesn't exist
#pip install bmi_nwis

# %%
import dataretrieval.nwis as nwis
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

site_id = '13185000'

#site_id = '13185000' Boise River at Twin Springs
#           '1313950' Big wood at Hailey
#           '13246000' N. Fork
#           '13042500' Henry's Fork near Island Park

# %%
dataset = nwis.get_record(sites = site_id, service='dv', start='1970-10-01', end='2020-09-30')
dataset
# Out:
#                            00010_Maximum 00010_Maximum_cd   site_no  \
# datetime
# 1970-10-01 00:00:00+00:00            NaN              NaN  13185000
# 1970-10-02 00:00:00+00:00            NaN              NaN  13185000
# 1970-10-03 00:00:00+00:00            NaN              NaN  13185000
# 1970-10-04 00:00:00+00:00            NaN              NaN  13185000
# 1970-10-05 00:00:00+00:00            NaN              NaN  13185000
# ...                                  ...              ...       ...
# 2020-09-26 00:00:00+00:00            NaN              NaN  13185000
# 2020-09-27 00:00:00+00:00            NaN              NaN  13185000
# 2020-09-28 00:00:00+00:00            NaN              NaN  13185000
# 2020-09-29 00:00:00+00:00            NaN              NaN  13185000
# 2020-09-30 00:00:00+00:00            NaN              NaN  13185000
#
#                            00010_Minimum 00010_Minimum_cd  00010_Mean  \
# datetime
# 1970-10-01 00:00:00+00:00            NaN              NaN         NaN
# 1970-10-02 00:00:00+00:00            NaN              NaN         NaN
# 1970-10-03 00:00:00+00:00            NaN              NaN         NaN
# 1970-10-04 00:00:00+00:00            NaN              NaN         NaN
# 1970-10-05 00:00:00+00:00            NaN              NaN         NaN
# ...                                  ...              ...         ...
# 2020-09-26 00:00:00+00:00            NaN              NaN         NaN
# 2020-09-27 00:00:00+00:00            NaN              NaN         NaN
# 2020-09-28 00:00:00+00:00            NaN              NaN         NaN
# 2020-09-29 00:00:00+00:00            NaN              NaN         NaN
# 2020-09-30 00:00:00+00:00            NaN              NaN         NaN
#
#                           00010_Mean_cd  00060_Mean 00060_Mean_cd
# datetime
# 1970-10-01 00:00:00+00:00           NaN       378.0             A
# 1970-10-02 00:00:00+00:00           NaN       375.0             A
# 1970-10-03 00:00:00+00:00           NaN       373.0             A
# 1970-10-04 00:00:00+00:00           NaN       369.0             A
# 1970-10-05 00:00:00+00:00           NaN       367.0             A
# ...                                 ...         ...           ...
# 2020-09-26 00:00:00+00:00           NaN       407.0             A
# 2020-09-27 00:00:00+00:00           NaN       417.0             A
# 2020-09-28 00:00:00+00:00           NaN       377.0             A
# 2020-09-29 00:00:00+00:00           NaN       372.0             A
# 2020-09-30 00:00:00+00:00           NaN       364.0             A
#
# [18263 rows x 9 columns]

# %%
type(dataset)
# Out:
# pandas.core.frame.DataFrame

# %%
dataset['00060_Mean'].plot()
# Out:
# <AxesSubplot:xlabel='datetime'>

# %%
dataset.groupby('datetime').max()
# Out:
#                            00010_Maximum 00010_Maximum_cd   site_no  \
# datetime
# 1970-10-01 00:00:00+00:00            NaN              NaN  13185000
# 1970-10-02 00:00:00+00:00            NaN              NaN  13185000
# 1970-10-03 00:00:00+00:00            NaN              NaN  13185000
# 1970-10-04 00:00:00+00:00            NaN              NaN  13185000
# 1970-10-05 00:00:00+00:00            NaN              NaN  13185000
# ...                                  ...              ...       ...
# 2020-09-26 00:00:00+00:00            NaN              NaN  13185000
# 2020-09-27 00:00:00+00:00            NaN              NaN  13185000
# 2020-09-28 00:00:00+00:00            NaN              NaN  13185000
# 2020-09-29 00:00:00+00:00            NaN              NaN  13185000
# 2020-09-30 00:00:00+00:00            NaN              NaN  13185000
#
#                            00010_Minimum 00010_Minimum_cd  00010_Mean  \
# datetime
# 1970-10-01 00:00:00+00:00            NaN              NaN         NaN
# 1970-10-02 00:00:00+00:00            NaN              NaN         NaN
# 1970-10-03 00:00:00+00:00            NaN              NaN         NaN
# 1970-10-04 00:00:00+00:00            NaN              NaN         NaN
# 1970-10-05 00:00:00+00:00            NaN              NaN         NaN
# ...                                  ...              ...         ...
# 2020-09-26 00:00:00+00:00            NaN              NaN         NaN
# 2020-09-27 00:00:00+00:00            NaN              NaN         NaN
# 2020-09-28 00:00:00+00:00            NaN              NaN         NaN
# 2020-09-29 00:00:00+00:00            NaN              NaN         NaN
# 2020-09-30 00:00:00+00:00            NaN              NaN         NaN
#
#                           00010_Mean_cd  00060_Mean 00060_Mean_cd
# datetime
# 1970-10-01 00:00:00+00:00           NaN       378.0             A
# 1970-10-02 00:00:00+00:00           NaN       375.0             A
# 1970-10-03 00:00:00+00:00           NaN       373.0             A
# 1970-10-04 00:00:00+00:00           NaN       369.0             A
# 1970-10-05 00:00:00+00:00           NaN       367.0             A
# ...                                 ...         ...           ...
# 2020-09-26 00:00:00+00:00           NaN       407.0             A
# 2020-09-27 00:00:00+00:00           NaN       417.0             A
# 2020-09-28 00:00:00+00:00           NaN       377.0             A
# 2020-09-29 00:00:00+00:00           NaN       372.0             A
# 2020-09-30 00:00:00+00:00           NaN       364.0             A
#
# [18263 rows x 9 columns]

# %%
dataset['00060_Mean'].groupby(dataset.index.year).max().plot()
# Out:
# <AxesSubplot:xlabel='datetime'>
